# %%
# Filtering Based on String

import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah", "Shakib"], 
"City": ["New York", "Los Angeles", "Newark", "Boston", "New Delhi", "Chicago", "New Orleans", "Houston", "H Los Ang"],
"Department": ["HR", "IT", "Finance", "IT", "HR", "Marketing", "Finance", "HR", "HR"],
"Salary": [50000, 60000, 55000, 70000, 52000, 58000, 62000, 51000, 500000]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 1      Bob  Los Angeles         IT   60000
# 2  Charlie       Newark    Finance   55000
# 3    David       Boston         IT   70000
# 4      Eve    New Delhi         HR   52000
# 5    Frank      Chicago  Marketing   58000
# 6    Grace  New Orleans    Finance   62000
# 7   Hannah      Houston         HR   51000
# 8   Shakib    H Los Ang         HR  500000

# %%
# Those City have New it will only print them

df.loc[df["City"].str.contains("New")]
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 2  Charlie       Newark    Finance   55000
# 4      Eve    New Delhi         HR   52000
# 6    Grace  New Orleans    Finance   62000

# %%
# To avoid case sensitivity
df.loc[df['City'].str.contains("new", case=False)]
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 2  Charlie       Newark    Finance   55000
# 4      Eve    New Delhi         HR   52000
# 6    Grace  New Orleans    Finance   62000

# %%
df.loc[df['City'].str.contains(r"Los")] # r = regular expression ($, ^, ., +)
# Out:
#      Name         City Department  Salary
# 1     Bob  Los Angeles         IT   60000
# 8  Shakib    H Los Ang         HR  500000

# %%
# Starts with Los usng (^)
df.loc[df['City'].str.contains(r"^Los")]
# Out:
#   Name         City Department  Salary
# 1  Bob  Los Angeles         IT   60000

# %%
# such word in df Ends with rk 
df.loc[df['City'].str.contains(r"rk$")]
# Out:
#       Name      City Department  Salary
# 0    Alice  New York         HR   50000
# 2  Charlie    Newark    Finance   55000

# %%
# Name starts with a vowel

df.loc[df['Name'].str.contains(r"^[AEIOU]")]
# Out:
#     Name       City Department  Salary
# 0  Alice   New York         HR   50000
# 4    Eve  New Delhi         HR   52000

# %%
# String contains New or Los
df.loc[df['City'].str.contains("New|Los")]
# Out:
#       Name         City Department  Salary
# 0    Alice     New York         HR   50000
# 1      Bob  Los Angeles         IT   60000
# 2  Charlie       Newark    Finance   55000
# 4      Eve    New Delhi         HR   52000
# 6    Grace  New Orleans    Finance   62000
# 8   Shakib    H Los Ang         HR  500000

# %%
# Adding  new Columnn and saving the file
df = pd.read_csv(r"..\student_data.csv")
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Adding a column with constant value

df['Country'] = 'Bangladesh'

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Addng a column from the result of sum(DS Marks, Algo Marks, Python Marks) But Nan values cant be added

df['Total Marks'] = df['Data Structure Marks']	+ df['Algorithm Marks'] + df['Python Marks']
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Filtaring and adding new column
import numpy as np

df['A+ in DS'] = np.where(df['Data Structure Marks']>=90, 'A+', 'A')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Adding column true false value. (boolean)
df['Passed in DS'] = df['Data Structure Marks']>70
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# spliting the Full Name

df['First Name'] = df['FullName'].str.split(' ').str[0]

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Before customizetion didn't change the main file
df1 = pd.read_csv('..\student_data.csv')

df1
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\arrah\AppData\Local\Temp\ipykernel_1984\3503215098.py:2: SyntaxWarning: invalid escape sequence '\s'
#   df1 = pd.read_csv('..\student_data.csv')
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# ...

# %%
# Save the copy of the main customised file

df.to_csv('new_data.csv')
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
new_df = pd.read_csv('new_data.csv')

new_df
# Out:
#     Unnamed: 0 StudentID          FullName  Data Structure Marks  \
# 0            0    PH1001       Alif Rahman                  85.0
# 1            1    PH1002     Fatima Akhter                  92.0
# 2            2    PH1003     Imran Hossain                  88.0
# 3            3    PH1004  Jannatul Ferdous                  78.0
# 4            4    PH1005       Kamal Uddin                   NaN
# 5            5    PH1006       Laila Begum                  75.0
# 6            6    PH1007    Mahmudul Hasan                  80.0
# 7            7    PH1008       Nadia Islam                  81.0
# 8            8    PH1009        Omar Faruq                  72.0
# 9            9    PH1010      Priya Sharma                  89.0
# 10          10    PH1011      Rahim Sheikh                   NaN
# 11          11    PH1012   Sadia Chowdhury                  85.0
# 12          12    PH1013      Tanvir Ahmed                  75.0
# ...

# %%
# Checking Duplicates and Null Values in DF

# Unique and nunique
data = {
"Name": ["Alice", "Bob", "Charlie", "Alice", "David", "Bob"],
"City": ["New York", "London", "Paris", "New York", "Tokyo", "London"],
"Score": [85, 90, 78, 85, 95, 90]
}

df = pd.DataFrame(data)
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     85
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
# Unique values (Unique only works on row, col {Series})
df['Name'].unique()

len(df['Name'].unique())
# Out:
# 4

# %%
df1
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df1['Data Structure Marks'].unique() # Here includes null values
# Out:
# array([85., 92., 88., 78., nan, 75., 80., 81., 72., 89., 86., 94., 90.])

# %%
df1['Data Structure Marks'].nunique() # Number of unique values without Null
# Out:
# 12

# %%
# nunique also works on a whole dataframe
df.nunique()
# Out:
# Name     4
# City     4
# Score    4
# dtype: int64

# %%
# Check Null
df1.isnull()
# Out:
#     StudentID  FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0       False     False                 False            False         False
# 1       False     False                 False            False          True
# 2       False     False                 False            False         False
# 3       False     False                 False            False         False
# 4       False     False                  True             True         False
# 5       False     False                 False            False         False
# 6       False     False                 False            False          True
# 7       False     False                 False            False         False
# 8       False     False                 False            False         False
# 9       False     False                 False            False         False
# 10      False     False                  True             True         False
# ...

# %%
df1['Data Structure Marks'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# Name: Data Structure Marks, dtype: bool

# %%
# Not Null
df1['Data Structure Marks'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# Name: Data Structure Marks, dtype: bool

# %%
# Checking in a column is here any null value
df1['Data Structure Marks'].hasnans
# Out:
# True

# %%
df1['StudentID'].hasnans
# Out:
# False

# %%
# Handling Duplicates Values

import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie", "Alice", "David", "Bob"],
"City": ["New York", "London", "Paris", "New York", "Tokyo", "London"],
"Score": [85, 90, 78, 70, 95, 90]
}

df2 = pd.DataFrame(data)
df2
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
# search duplicate rows

df2.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
# deleting duplicates values (copy)
df2.drop_duplicates()
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
df2
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
# permanent Delete
df2.drop_duplicates(inplace=True)

# %%
df2
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
# Remove duplicate from column
df2.drop_duplicates(subset=['Name'])
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 4    David     Tokyo     95

# %%
df2
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
# Keep keyword keeps the first or last value. in default keeps the 1st
df.drop_duplicates(subset=['City'], keep='last')
# Out:
#       Name      City  Score
# 2  Charlie     Paris     78
# 3    Alice  New York     85
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
# Handling Null Values

df3= pd.read_csv(r'..\student_data.csv')
df3
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# drop null value rows
df3.dropna()
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
# Delete that row whos every value is null

df3.dropna(how='all', inplace=True)  # default- df.dropna(how='any')

# %%
df3
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Delete row according column

df3.dropna(subset=['Python Marks'])
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# ...

# %%
df3.dropna(subset=['Python Marks', 'Algorithm Marks'])
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
# replace the null with a value
df.fillna(0)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   0.0              0.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   0.0              0.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# change according column
df['FullName'].fillna('unknown')
# Out:
# 0          Alif Rahman
# 1        Fatima Akhter
# 2        Imran Hossain
# 3     Jannatul Ferdous
# 4          Kamal Uddin
# 5          Laila Begum
# 6       Mahmudul Hasan
# 7          Nadia Islam
# 8           Omar Faruq
# 9         Priya Sharma
# 10        Rahim Sheikh
# 11     Sadia Chowdhury
# 12        Tanvir Ahmed
# 13          Urmi Akter
# 14        Wahiduzzaman
# 15        Ziaur Rahman
# 16         Afsana Mimi
# 17         Babul Ahmed
# 18        Faria Rahman
# 19          Nasir Khan
# Name: FullName, dtype: object

# %%
df['Python Marks'].fillna(df['Python Marks'].mean(), inplace=True)
df
# Out:
# C:\Users\arrah\AppData\Local\Temp\ipykernel_740\863428798.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Python Marks'].fillna(df['Python Marks'].mean(), inplace=True)
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# ...

# %%
# Statistical Function in Pandas
df.dropna()
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
# sum from column
df['Data Structure Marks'].sum()
# Out:
# np.float64(1344.0)

# %%
# Max of a column
df['Data Structure Marks'].max()
# Out:
# np.float64(94.0)

# %%
# Min of a column
df['Data Structure Marks'].min()
# Out:
# np.float64(72.0)

# %%
# Mean -> average
df['Data Structure Marks'].mean()
# Out:
# np.float64(84.0)

# %%
# Median
df['Data Structure Marks'].median()
# Out:
# np.float64(85.5)

# %%
# Mode -> highest frequency numbers
df['Data Structure Marks'].mode()
# Out:
# 0    75.0
# 1    85.0
# 2    86.0
# 3    88.0
# Name: Data Structure Marks, dtype: float64

# %%
# Standard deviation (std)
df['Data Structure Marks'].std()
# Out:
# np.float64(6.501281924871945)

# %%
# Correlation Matrix
df[['Data Structure Marks', 'Algorithm Marks']].corr()
# Out:
#                       Data Structure Marks  Algorithm Marks
# Data Structure Marks                   1.0              1.0
# Algorithm Marks                        1.0              1.0

# %%
df[['Data Structure Marks', 'Python Marks']].corr()
# Out:
#                       Data Structure Marks  Python Marks
# Data Structure Marks              1.000000      0.893455
# Python Marks                      0.893455      1.000000

# %%
# Sum in different columns
df[['Data Structure Marks', 'Python Marks']].sum()
# Out:
# Data Structure Marks    1344.0
# Python Marks            1285.0
# dtype: float64

# %%
# sum according row of columns. (Every number of python and DS is summed row wise)
df[['Data Structure Marks', 'Python Marks']].sum(axis=1)
# Out:
# 0     173.0
# 1      92.0
# 2     173.0
# 3     160.0
# 4      95.0
# 5     153.0
# 6      80.0
# 7     166.0
# 8     148.0
# 9     177.0
# 10     91.0
# 11    172.0
# 12    154.0
# 13      0.0
# 14    170.0
# 15     94.0
# 16    183.0
# 17    173.0
# 18      0.0
# 19    175.0
# dtype: float64

# %%
# Sum of many columns
   # its not fruitful -> df['Total'] = df['DS'] + df['Algo'] + df['py']

df['Total Marks'] = df.iloc[::,2:5].sum(axis=1) # iloc[rows range, column range]

df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Apply custom function on df

    # min max scaling (scaled = (x-mn)/(mx-mn))
mn = df['Total Marks'].min()
mx = df['Total Marks'].max()   

df['Scaled Marks'] = df['Total Marks'].apply(lambda x: (x-mn)/(mx-mn))
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Custom Built Function

def grading_system(marks):
    if marks >= 260:
        return 'A+'
    elif marks >=250:
        return 'A'
    else:
        return 'A-'

df['Grade'] = df['Total Marks'].apply(grading_system)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
def marking_sysem(df):
    a = df['Data Structure Marks'] * 2
    b = df['Python Marks'] * 3
    c = df['Algorithm Marks'] * 4
    
    return a + b + c

df['Exceptional Marks'] = df.apply(marking_sysem, axis=1)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# DateTime and Timedelta

df4 = pd.read_csv(r'..\student_completed_data.csv')
df4
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
df4['EnrollmentDate']
# Out:
# 0     2024-09-01
# 1     2024-08-11
# 2     2024-05-08
# 3     2024-07-05
# 4     2024-02-01
# 5     2024-09-07
# 6     2024-06-07
# 7     2024-03-22
# 8     2024-02-12
# 9     2024-06-19
# 10    2024-03-14
# 11    2024-08-04
# 12    2024-06-07
# 13    2024-01-04
# 14    2024-02-22
# 15    2024-03-23
# 16    2024-01-18
# 17    2024-06-23
# 18    2024-04-19
# 19    2024-07-21
# Name: EnrollmentDate, dtype: object

# %%
# coverting data type to date time. previous it ws object
df4['EnrollmentDate'] = pd.to_datetime(df['EnrollmentDate'])
df4['EnrollmentDate']
# Out:
# 0    2024-01-15
# 1    2024-01-20
# 2    2024-02-10
# 3    2024-02-12
# 4    2024-03-05
# 5    2024-03-08
# 6    2024-04-01
# 7    2024-04-22
# 8    2024-05-16
# 9    2024-05-20
# 10   2024-06-11
# 11   2024-06-14
# 12   2024-07-02
# 13   2024-07-09
# 14   2024-08-18
# 15   2024-08-21
# 16   2025-09-01
# 17   2025-09-05
# 18   2025-09-15
# 19   2025-10-02
# Name: EnrollmentDate, dtype: datetime64[ns]

# %%
# Extracting the year
df4['Enrollment Year'] = df4['EnrollmentDate'].dt.year
df4
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-01-15   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-01-20   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-02-10   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-02-12   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-03-05   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-03-08   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-04-01   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-04-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-05-16   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-05-20   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-06-11   2024-06-11
# ...

# %%
# Extracting the day
df4['Enrollment Date'] = df4['EnrollmentDate'].dt.day
df4
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-01-15   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-01-20   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-02-10   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-02-12   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-03-05   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-03-08   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-04-01   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-04-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-05-16   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-05-20   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-06-11   2024-06-11
# ...

# %%
df4['FinishedDate'] = pd.to_datetime(df4['FinishedDate'])
df4['EnrollmentDate'] = pd.to_datetime(df4['EnrollmentDate'])

# %%
df4['Time taken to finish'] = df4['FinishedDate'] - df4['EnrollmentDate']
df4
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-01-15   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-01-20   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-02-10   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-02-12   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-03-05   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-03-08   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-04-01   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-04-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-05-16   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-05-20   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-06-11   2024-06-11
# ...

# %%
df4.drop(columns=['StudentID', 'FullName', 'CompletionStatus'], inplace=True)

# %%
# Groupby in DF.

group = df4.groupby('Instructor')
group.sum()
# Out:
#                                                EnrollmentDate  \
# Instructor
# Mr. David   2024-02-012024-09-072024-06-072024-06-192024-0...
# Mr. Karim   2024-08-112024-07-052024-02-122024-03-142024-0...
# Ms. Salma            2024-09-012024-05-082024-03-222024-03-23
#
#                                                  FinishedDate  \
# Instructor
# Mr. David   2024-04-172024-12-312024-07-202024-08-192024-0...
# Mr. Karim   2024-11-072024-09-232024-06-082024-06-112024-1...
# Ms. Salma            2024-12-232024-08-082024-05-012024-06-21
#
#                                                      Location  Total Marks
# Instructor
# Mr. David   SylhetKhulnaChattogramDhakaDhakaSylhetRajshahi...         2399
# Mr. Karim            DhakaKhulnaDhakaSylhetSylhetSylhetKhulna         1911
# Ms. Salma                           KhulnaDhakaKhulnaRajshahi         1049

# %%
group.min()
# Out:
#            EnrollmentDate FinishedDate    Location  Total Marks
# Instructor
# Mr. David      2024-01-04   2024-03-16  Chattogram          236
# Mr. Karim      2024-02-12   2024-06-08       Dhaka          253
# Ms. Salma      2024-03-22   2024-05-01       Dhaka          234

# %%
group.max()
# Out:
#            EnrollmentDate FinishedDate  Location  Total Marks
# Instructor
# Mr. David      2024-09-07   2024-12-31    Sylhet          291
# Mr. Karim      2024-08-11   2024-11-07    Sylhet          291
# Ms. Salma      2024-09-01   2024-12-23  Rajshahi          300

# %%
# to see first student info of every group
group.first()
# Out:
#            EnrollmentDate FinishedDate Location  Total Marks
# Instructor
# Mr. David      2024-02-01   2024-04-17   Sylhet          254
# Mr. Karim      2024-08-11   2024-11-07    Dhaka          271
# Ms. Salma      2024-09-01   2024-12-23   Khulna          300

# %%
# to see last student info of every group
group.last()
# Out:
#            EnrollmentDate FinishedDate  Location  Total Marks
# Instructor
# Mr. David      2024-06-23   2024-09-20     Dhaka          278
# Mr. Karim      2024-07-21   2024-10-11    Khulna          253
# Ms. Salma      2024-03-23   2024-06-21  Rajshahi          234
